# %% [markdown]
# # 0) Modules & Functions

# %%
import os
import pandas as pd
from rdkit import Chem
import subprocess
import hashlib
import tempfile
import base64
import numpy as np
from itertools import combinations
from scipy.stats import pearsonr
from tqdm import tqdm
import time
from collections import defaultdict
from rdkit.Chem import AllChem
from rdkit import RDLogger
import warnings
import re
from rdkit.Chem import inchi
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from rdkit.Chem import Descriptors

# Disable RDKit warnings
RDLogger.DisableLog('rdApp.*')

warnings.filterwarnings("ignore", category=UserWarning, module="rdkit")
warnings.filterwarnings("ignore", category=FutureWarning, module="rdkit")
warnings.filterwarnings("ignore", category=DeprecationWarning, module="rdkit")

class MMPGenerator:
    def __init__(self, df_input, output_csv, mmpa_dir='../mmpa',
                 symmetric=True, max_heavy=14, max_ratio=0.7, verbose=True):
        self.df_original = df_input.copy()
        self.output_csv = output_csv
        self.mmpa_dir = mmpa_dir
        self.symmetric = symmetric
        self.max_heavy = max_heavy
        self.max_ratio = max_ratio
        self.verbose = verbose

    def _get_inchikey(self, smiles):
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            return Chem.inchi.MolToInchiKey(mol)
        return self.encode_string(smiles)

    def encode_string(self, s):
        return base64.urlsafe_b64encode(s.encode()).decode()

    def decode_string(self, b64):
        return base64.urlsafe_b64decode(b64.encode()).decode()

    def run(self):
        self.df_original['ID'] = [self._get_inchikey(smi) for smi in self.df_original['SMILES']]
        y_map = self.df_original.set_index('ID')['Y'].to_dict()

        with tempfile.TemporaryDirectory() as tmp:
            smi_path = os.path.join(tmp, 'input.smi')
            frag_path = os.path.join(tmp, 'fragmented.txt')
            mmps_path = os.path.join(tmp, 'mmps.csv')
            smirks_path = os.path.join(tmp, 'smirks.txt')
            cansmirks_path = os.path.join(tmp, 'cansmirks.txt')

            self.df_original[['SMILES', 'ID']].to_csv(smi_path, index=False, sep=' ', header=False)

            print("0) Fragments generation")
            with open(frag_path, 'w') as out:
                subprocess.run(['python', f'{self.mmpa_dir}/rfrag.py'], stdin=open(smi_path), stdout=out)

            print("1) Indexing")
            cmd = ['python', f'{self.mmpa_dir}/indexing.py']
            if self.symmetric:
                cmd.append('-s')
            if self.max_heavy:
                cmd.extend(['-m', str(self.max_heavy)])
            if self.max_ratio:
                cmd.extend(['-r', str(self.max_ratio)])

            with open(mmps_path, 'w') as out:
                subprocess.run(cmd, stdin=open(frag_path), stdout=out)

            with open(mmps_path) as f:
                lines = [line.strip() for line in f if line.strip()]


            splits = [line.split(',') for line in lines]
            max_len = max(len(s) for s in splits)

            df = pd.DataFrame(splits, columns=['L_SMILES', 'R_SMILES', 'L_ID', 'R_ID', 'SMIRKS', 'CORE'])


            df['L_Y'] = df['L_ID'].map(y_map)
            df['R_Y'] = df['R_ID'].map(y_map)
            df['Delta_Y'] = df['R_Y'] - df['L_Y']

            df = df[df['SMIRKS'].apply(lambda x: isinstance(x, str) and '>>' in x)]

            df['__row'] = range(len(df))
            df[['SMIRKS', '__row']].to_csv(smirks_path, index=False, sep=' ', header=False)

            print("2) Canonical SMIRKS generation")
            with open(cansmirks_path, 'w') as out:
                subprocess.run(['python', f'{self.mmpa_dir}/cansmirk.py'], stdin=open(smirks_path), stdout=out)


            canon_df = pd.read_csv(cansmirks_path, sep=' ', names=['Canonical_SMIRKS', 'index'])


            df = df.merge(canon_df, left_on='__row', right_on='index').drop(columns=['__row', 'index'])

            df[['L_sub', 'R_sub']] = df['Canonical_SMIRKS'].str.split('>>', expand=True)


            df['L_sub_ID'] = [self.encode_string(k) for k in df['L_sub'].tolist()]
            df['R_sub_ID'] = [self.encode_string(k) for k in df['R_sub'].tolist()]
            df['SMIRKS_ID'] = [self.encode_string(k) for k in df['Canonical_SMIRKS'].tolist()]
            df['CORE_ID'] = [self.encode_string(k) for k in df['CORE'].tolist()]
            df = df.drop_duplicates()


            df[['L_SMILES', 'R_SMILES', 'L_ID', 'R_ID', 'SMIRKS', 'CORE', 'L_Y', 'R_Y', 'Delta_Y', 'L_sub', 'R_sub', 'L_sub_ID', 'R_sub_ID', 'SMIRKS_ID', 'CORE_ID']].to_csv(
                self.output_csv, index=False
            )


class MMPAugmentorFixed:
    def __init__(self, df, min_common=4, pearson_thresh=0.3, crmsd_thresh=0.4):
        self.df = df.copy()
        self.min_common = min_common
        self.pearson_thresh = pearson_thresh
        self.crmsd_thresh = crmsd_thresh
        self.series = {}
        self.pair_scores = []
        self.filtered_pairs = []
        self.augmented_data = []

    def _extract_series(self):
        start = time.time()
        self.series = {
            core: group for core, group in self.df.groupby("CORE")
        }

    def _compute_pairwise_scores(self):
        start = time.time()
        self.pair_scores = []
        series_items = list(self.series.items())
        total_combinations = len(series_items) * (len(series_items) - 1) // 2
        for (core1, df1), (core2, df2) in tqdm(combinations(series_items, 2), desc="3) Computing pairwise correlations", total=total_combinations):
            subs1 = set(df1["L_sub"])
            subs2 = set(df2["L_sub"])
            common = subs1 & subs2
            if len(common) < self.min_common:
                continue

            merged = pd.merge(
                df1, df2,
                left_on=["L_sub", "R_sub"],
                right_on=["L_sub", "R_sub"],
                suffixes=('_1', '_2')
            )
            if len(merged) < self.min_common:
                continue

            y1 = merged['Delta_Y_1'].values
            y2 = merged['Delta_Y_2'].values
            crmsd = np.sqrt(np.mean((y1 - y2) ** 2))
            try:
                corr = pearsonr(y1, y2)[0]
            except:
                corr = np.nan

            self.pair_scores.append((core1, core2, crmsd, corr, len(merged)))

    def _filter_pairs(self):
        start = time.time()
        self.filtered_pairs = [
            (s1, s2) for s1, s2, rmsd, corr, n in self.pair_scores
            if rmsd <= self.crmsd_thresh and (not np.isnan(corr) and corr >= self.pearson_thresh)
        ]

    def _augment(self):
        start = time.time()
        augmented_entries = []

        for s1, s2 in tqdm(self.filtered_pairs, desc="4) Augmenting data"):
            df1 = self.series[s1]
            df2 = self.series[s2]

            tf1 = df1[["L_sub", "R_sub", "Delta_Y"]].to_dict("records")
            tf2 = df2[["L_sub", "R_sub", "Delta_Y"]].to_dict("records")

            df1_dict = defaultdict(list)
            for _, row in df1.iterrows():
                df1_dict[row["L_sub"]].append(row.to_dict())

            df2_dict = defaultdict(list)
            for _, row in df2.iterrows():
                df2_dict[row["L_sub"]].append(row.to_dict())

            for entry in tf1:
                l_sub = entry["L_sub"]
                for base in df2_dict.get(l_sub, []):
                    r_sub = entry["R_sub"]
                    delta = entry["Delta_Y"]
                    new_y = base["L_Y"] + delta
                    smirks_new = l_sub + ">>" + r_sub
                    augmented_entries.append({
                        "CORE": s1,
                        "L_sub": l_sub,
                        "R_sub": r_sub,
                        "L_Y": base["L_Y"],
                        "R_Y": new_y,
                        "Delta_Y": delta,
                        "AUG": True,
                        "L_SMILES": base.get("L_SMILES"),
                        "L_ID": base.get("L_ID"),
                        "L_sub_ID": base.get("L_sub_ID"),
                        "R_sub_ID": base64.urlsafe_b64encode(r_sub.encode()).decode(),
                        "SMIRKS": smirks_new,
                        "SMIRKS_ID": base64.urlsafe_b64encode(smirks_new.encode()).decode(),
                        "CORE_ID": base64.urlsafe_b64encode(s1.encode()).decode()
                    })

            for entry in tf2:
                l_sub = entry["L_sub"]
                for base in df1_dict.get(l_sub, []):
                    r_sub = entry["R_sub"]
                    delta = entry["Delta_Y"]
                    new_y = base["L_Y"] + delta
                    smirks_new = l_sub + ">>" + r_sub
                    augmented_entries.append({
                        "CORE": s2,
                        "L_sub": l_sub,
                        "R_sub": r_sub,
                        "L_Y": base["L_Y"],
                        "R_Y": new_y,
                        "Delta_Y": delta,
                        "AUG": True,
                        "L_SMILES": base.get("L_SMILES"),
                        "L_ID": base.get("L_ID"),
                        "L_sub_ID": base.get("L_sub_ID"),
                        "R_sub_ID": base64.urlsafe_b64encode(r_sub.encode()).decode(),
                        "SMIRKS": smirks_new,
                        "SMIRKS_ID": base64.urlsafe_b64encode(smirks_new.encode()).decode(),
                        "CORE_ID": base64.urlsafe_b64encode(s2.encode()).decode()
                    })

        self.augmented_data = pd.DataFrame(augmented_entries)


    def run(self):
        self._extract_series()
        self._compute_pairwise_scores()
        self._filter_pairs()
        self._augment()

        original = self.df.copy()
        original["AUG"] = False
        return pd.concat([original, self.augmented_data], ignore_index=True)
    
    def get_pair_scores_df(self):
        """
        Return a DataFrame of scaffold pair scores (cRMSD, Pearson, common MMP count)
        """
        return pd.DataFrame(
            self.pair_scores,
            columns=["Scaffold_1", "Scaffold_2", "cRMSD", "Pearson", "N_common"]
        )

    def get_augmented_only(self):
        """
        Return only the augmented (predicted) entries.
        """
        return self.augmented_data.copy()
    

def analyze_scaffold_pair_scores(df):
    summary = {
        "Total Pairs": len(df),
        "Mean cRMSD": df["cRMSD"].mean(),
        "Median cRMSD": df["cRMSD"].median(),
        "Std cRMSD": df["cRMSD"].std(),
        "Mean Pearson": df["Pearson"].mean(),
        "Median Pearson": df["Pearson"].median(),
        "Std Pearson": df["Pearson"].std(),
        "Mean N_common": df["N_common"].mean(),
        "Median N_common": df["N_common"].median()
    }

    high_corr = df["Pearson"] > 0.7
    low_crmsd = df["cRMSD"] < 0.5
    enough_common = df["N_common"] >= 5
    strong_pairs = df[high_corr & low_crmsd & enough_common]

    summary.update({
        "High Pearson (>0.7)": high_corr.sum(),
        "Low cRMSD (<0.5)": low_crmsd.sum(),
        "N_common ≥ 5": enough_common.sum(),
        "Strong Pairs (all 3)": len(strong_pairs)
    })

    top_corr = df.sort_values("Pearson", ascending=False).head(5)
    top_low_crmsd = df.sort_values("cRMSD").head(5)
    top_common = df.sort_values("N_common", ascending=False).head(5)

    return {
        "summary": summary,
        "top_corr": top_corr,
        "top_low_crmsd": top_low_crmsd,
        "top_common": top_common,
        "strong_pairs": strong_pairs
    }




def fast_apply_transformation(transformation, l_smiles, rxn_cache, core_cache, heavy_cache, core_smarts, failure_tracker=None):
    if pd.isna(transformation) or pd.isna(l_smiles):
        return None

    # --- Cache reaction and Δheavy ---
    if transformation not in rxn_cache:
        try:
            rxn = AllChem.ReactionFromSmarts(transformation)
            left_smi, right_smi = transformation.split(">>")
            left_mol = Chem.MolFromSmarts(left_smi)
            right_mol = Chem.MolFromSmarts(right_smi)
            delta_heavy = right_mol.GetNumHeavyAtoms() - left_mol.GetNumHeavyAtoms()
            rxn_cache[transformation] = (rxn, delta_heavy)
        except:
            return None
    else:
        rxn, delta_heavy = rxn_cache[transformation]

    # --- Cache L_SMILES heavy atom count ---
    if l_smiles not in heavy_cache:
        mol_l = Chem.MolFromSmiles(l_smiles)
        if mol_l is None:
            return None
        n_heavy_l = mol_l.GetNumHeavyAtoms()
        heavy_cache[l_smiles] = (mol_l, n_heavy_l)
    else:
        mol_l, n_heavy_l = heavy_cache[l_smiles]

    # --- Cache core mol ---
    if core_smarts not in core_cache:
        core_mol = Chem.MolFromSmarts(core_smarts)
        if core_mol is None:
            return None
        core_cache[core_smarts] = core_mol
    else:
        core_mol = core_cache[core_smarts]

    # --- Run reaction ---
    try:
        products = rxn.RunReactants((mol_l,))
    except Exception:
        return None

    if failure_tracker is not None:
        failure_tracker["total"] += 1
        if not products:
            failure_tracker["empty_prodsets"] += 1

    all_products = []
    for prod_set in products:
        if not prod_set and failure_tracker is not None:
            failure_tracker["empty_prodsets"] += 1
        for prod in prod_set:
            if prod is None:
                continue
            try:
                if not prod.HasSubstructMatch(core_mol):
                    continue
            except:
                continue
            n_heavy_r = prod.GetNumHeavyAtoms()
            if n_heavy_r - n_heavy_l != delta_heavy:
                continue
            all_products.append(Chem.MolToSmiles(prod, isomericSmiles=True))

    return all_products if all_products else None

def update_predicted_rows(df):
    df = df.drop_duplicates()
    mask = df["AUG"] == True
    indices = df[mask].index

    rxn_cache = {}
    heavy_cache = {}
    core_cache = {}

    new_rows = []
    failure_tracker = {"total": 0, "empty_prodsets": 0}

    for idx in tqdm(indices, desc="5) Updating predicted rows"):
        row = df.loc[idx]
        l_smiles = row["L_SMILES"]
        smirks = row["SMIRKS"]
        core = row["CORE"]

        r_smiles_list = fast_apply_transformation(
            smirks, l_smiles, rxn_cache, core_cache, heavy_cache, core,
            failure_tracker=failure_tracker
        )

        if r_smiles_list:
            for r_smiles in r_smiles_list:
                mol = Chem.MolFromSmiles(r_smiles)
                if mol:
                    r_id = Chem.InchiToInchiKey(Chem.MolToInchi(mol))
                    new_row = row.copy()
                    new_row["R_SMILES"] = r_smiles
                    new_row["R_ID"] = r_id
                    new_rows.append(new_row)

    df_non_aug = df[~mask]
    df_aug_expanded = pd.DataFrame(new_rows)
    df_final = pd.concat([df_non_aug, df_aug_expanded], ignore_index=True)

    # Print failure rate
    total = failure_tracker["total"]
    failed = failure_tracker["empty_prodsets"]
    if total > 0:
        print(f"⚠️  Empty product sets in {failed} / {total} ({100 * failed / total:.2f}%) of transformations")

    return df_final








def prepare_and_plot_prediction_vs_experiment_complete_with_output(imputed_df, std_threshold=0.5):

    print("6) Preparing output file")

    l_df = imputed_df[["L_SMILES", "L_Y", "AUG"]]
    r_df = imputed_df[["R_SMILES", "R_Y", "AUG"]]
    l_df.columns = ["SMILES", "Y", "AUG"]
    r_df.columns = ["SMILES", "Y", "AUG"]
    clean_df = pd.concat([l_df, r_df])


    # Count total before
    total_before = len(clean_df)

    # Drop rows with missing or invalid SMILES
    clean_df = clean_df.dropna(subset=["SMILES"]).copy()
    clean_df = clean_df[clean_df["SMILES"].apply(lambda x: Chem.MolFromSmiles(x) is not None)]

    # Count total after
    total_after = len(clean_df)

    # Print failure rate
    fail_pct = 100 * (total_before - total_after) / total_before
    print(f"Invalid SMILES removed: {total_before - total_after} / {total_before} ({fail_pct:.2f}%)")

    tqdm.pandas(desc="7) Standardizing SMILES")
    clean_df["SMILES"] = clean_df["SMILES"].progress_apply(
        lambda x: Chem.MolToSmiles(Chem.MolFromSmiles(x), isomericSmiles=True)
    )

    # Step 8) InChIKey generation
    tqdm.pandas(desc="8) Generating InChIKeys")
    clean_df['InChIKey'] = clean_df["SMILES"].progress_apply(smiles_to_inchikey)


    # Insert InChIKey as first column
    cols = ['InChIKey'] + [col for col in clean_df.columns if col != 'InChIKey']
    clean_df = clean_df[cols]


    clean_df_exp = clean_df[clean_df["AUG"] != True].copy()
    clean_df_pred = clean_df[clean_df["AUG"] == True].copy()

    # Normalize column names
    clean_df_exp = clean_df_exp.rename(columns={"R_SMILES": "SMILES", "R_Y": "Y"})
    clean_df_pred = clean_df_pred.rename(columns={"R_SMILES": "SMILES", "R_Y": "Y"})

    # Compute median and std per SMILES in predicted
    grouped_pred = clean_df_pred.groupby("InChIKey")["Y"].agg(["median", "std"]).reset_index()
    grouped_pred.columns = ["InChIKey", "Y", "STD"]
    grouped_pred["AUG"] = True

    # Re-add SMILES by mapping InChIKey → first SMILES in original pred dataframe
    inchikey_to_smiles = clean_df_pred.dropna(subset=["SMILES"]).drop_duplicates("InChIKey").set_index("InChIKey")["SMILES"].to_dict()
    grouped_pred["SMILES"] = grouped_pred["InChIKey"].map(inchikey_to_smiles)
    grouped_pred = grouped_pred[["InChIKey", "SMILES", "Y", "STD", "AUG"]]
    grouped_pred = grouped_pred[grouped_pred["STD"]<= std_threshold]

    # Final prediction rows
    exp_out = clean_df_exp[['InChIKey', "SMILES", "Y"]].copy()
    exp_out["STD"] = None
    exp_out["AUG"] = False
    exp_out = exp_out[["InChIKey", "SMILES", "Y", "STD", "AUG"]]

    exp_out = exp_out.dropna(how='all')
    grouped_pred = grouped_pred.dropna(how='all')

    # Remove predicted entries with InChIKey already in experimental
    known_keys = set(exp_out['InChIKey'])
    grouped_pred = grouped_pred[~grouped_pred['InChIKey'].isin(known_keys)]


    output_df = pd.concat(
    [exp_out.drop_duplicates("InChIKey"), grouped_pred.drop_duplicates("InChIKey")],
    ignore_index=True
    )

    output_df = output_df[~((output_df['AUG'] == True) & (output_df['InChIKey'].isin(output_df.loc[output_df['AUG'] == False, 'InChIKey'])))]

    return output_df


# Compute InChIKey from SMILES
def smiles_to_inchikey(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None
    try:
        return inchi.MolToInchiKey(mol)
    except:
        return None
    

def assign_set_from_inchikey(output_df, reference_df, smiles_col="SMILES", inchikey_col="InChIKey", set_col="SET"):
    # Compute InChIKey for each SMILES in output_df
    output_df[inchikey_col] = output_df[smiles_col].apply(
        lambda smi: Chem.inchi.MolToInchiKey(Chem.MolFromSmiles(smi)) if Chem.MolFromSmiles(smi) else None
    )
    
    # Create lookup from reference_df
    inchikey_map = dict(zip(reference_df[inchikey_col], reference_df[set_col]))
    
    # Map SET
    output_df[set_col] = output_df[inchikey_col].map(inchikey_map)
    
    return output_df


def smiles_to_morgan(smiles, radius=3, n_bits=4096):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return np.zeros(n_bits)
    return np.array(AllChem.GetMorganFingerprintAsBitVect(mol, radius, nBits=n_bits))

def train_and_compare_models(output_df, random_state=29121997):
    print("🔬 Starting model training and comparison...")

    # --- Step 1: Compute Morgan fingerprints for all molecules ---
    tqdm.pandas(desc="Generating fingerprints")
    output_df_ML = output_df.copy()
    output_df_ML["FP"] = output_df_ML["SMILES"].progress_apply(smiles_to_morgan)

    # --- Step 2: Split into training and testing sets ---
    train_df = output_df_ML[(output_df_ML["SET"].isin(["A","B"])==True) & (output_df_ML["AUG"] == False)]
    aug_df = output_df_ML[output_df_ML["AUG"] == True]
    test_df = output_df_ML[output_df_ML["SET"].isin(["A","B"])==False]

    # --- Step 3: Format X and y ---
    def get_X_y(df):
        X = np.stack(df["FP"].values)
        y = df["Y"].values
        return X, y

    X_train_no_aug, y_train_no_aug = get_X_y(train_df)
    X_train_aug, y_train_aug = get_X_y(pd.concat([train_df, aug_df], ignore_index=True))
    X_test, y_test = get_X_y(test_df)

    # --- Step 4: Train models ---
    model_no_aug = RandomForestRegressor(n_estimators=200, random_state=random_state, n_jobs=-1)
    model_aug = RandomForestRegressor(n_estimators=200, random_state=random_state, n_jobs=-1)

    print("🚜 Training on raw train set (no AUG)...")
    model_no_aug.fit(X_train_no_aug, y_train_no_aug)

    print("🌱 Training on train + AUG data...")
    model_aug.fit(X_train_aug, y_train_aug)

    # --- Step 5: Predict on test set ---
    y_pred_no_aug = model_no_aug.predict(X_test)
    y_pred_aug = model_aug.predict(X_test)

    # --- Step 6: Compute metrics ---
    def report_metrics(y_true, y_pred, label):
        rmse = mean_squared_error(y_true, y_pred, squared=False)
        r2 = r2_score(y_true, y_pred)
        print(f"{label} => RMSE: {rmse:.4f}, R²: {r2:.4f}")
        return rmse, r2

    print("\n📊 Evaluation on test set:")
    rmse_no_aug, r2_no_aug = report_metrics(y_test, y_pred_no_aug, "Baseline model (no AUG)")
    rmse_aug, r2_aug = report_metrics(y_test, y_pred_aug, "Augmented model (with AUG)")

    return {
        "RMSE_NoAug": rmse_no_aug,
        "R2_NoAug": r2_no_aug,
        "RMSE_Aug": rmse_aug,
        "R2_Aug": r2_aug,
        "N_Train_NoAug": len(X_train_no_aug),
        "N_Train_Aug": len(X_train_aug)
    }


from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
from tqdm import tqdm

def train_and_compare_models_external(output_df, test_set, random_state=29121997):
    print("🔬 Starting model training on external test set...")

    # Compute Morgan fingerprints
    tqdm.pandas(desc="Generating fingerprints (train)")
    output_df = output_df.copy()
    output_df["FP"] = output_df["SMILES"].progress_apply(smiles_to_morgan)

    tqdm.pandas(desc="Generating fingerprints (test)")
    test_set = test_set.copy()
    test_set["FP"] = test_set["SMILES"].progress_apply(smiles_to_morgan)

    # Split training: augmented vs no-augmented
    train_df_noaug = output_df[output_df["AUG"] == False]
    train_df_aug = output_df  # full output_df includes AUG

    def get_X_y(df):
        X = np.stack(df["FP"].values)
        y = df["Y"].values
        return X, y

    X_train_noaug, y_train_noaug = get_X_y(train_df_noaug)
    X_train_aug, y_train_aug = get_X_y(train_df_aug)
    X_test, y_test = get_X_y(test_set)

    model_noaug = RandomForestRegressor(n_estimators=300, random_state=random_state, n_jobs=-1)
    model_aug = RandomForestRegressor(n_estimators=300, random_state=random_state, n_jobs=-1)

    print("🚜 Training on no-aug data...")
    model_noaug.fit(X_train_noaug, y_train_noaug)

    print("🌱 Training on full augmented data...")
    model_aug.fit(X_train_aug, y_train_aug)

    y_pred_noaug = model_noaug.predict(X_test)
    y_pred_aug = model_aug.predict(X_test)

    def report_metrics(y_true, y_pred, label):
        rmse = mean_squared_error(y_true, y_pred, squared=False)
        r2 = r2_score(y_true, y_pred)
        print(f"{label} => RMSE: {rmse:.4f}, R²: {r2:.4f}")
        return rmse, r2

    print("\n📊 Evaluation on external test set:")
    rmse_noaug, r2_noaug = report_metrics(y_test, y_pred_noaug, "No AUG model")
    rmse_aug, r2_aug = report_metrics(y_test, y_pred_aug, "AUG model")

    return {
        "RMSE_NoAug": rmse_noaug,
        "R2_NoAug": r2_noaug,
        "RMSE_Aug": rmse_aug,
        "R2_Aug": r2_aug,
        "N_Train_NoAug": len(train_df_noaug),
        "N_Train_Aug": len(train_df_aug),
        "N_Test": len(test_set)
    }

from rdkit import Chem
from rdkit.Chem import Draw


def show_top_aug_vs_nonaug(output_df, n=8):
    # Sort by SMILES then AUG=False before AUG=True
    sorted_df = output_df.sort_values(by=["SMILES", "AUG"], ascending=[True, False])
    
    # Select top non-augmented and augmented
    top_nonaug = sorted_df[sorted_df["AUG"] == False].head(n)
    top_aug = sorted_df[sorted_df["AUG"] == True].head(n)

    combined = pd.concat([top_nonaug, top_aug])
    mols = [Chem.MolFromSmiles(s) for s in combined["SMILES"]]

    legends = [f'{i+1}. {row["InChIKey"][:8]} | {row["Y"]:.2f}' for i, row in combined.iterrows()]
    img = Draw.MolsToGridImage(mols, molsPerRow=4, subImgSize=(400, 400), legends=legends, useSVG=False)
    return img

# %% [markdown]
# # 1) Parameters

# %%
max_heavy = 20
max_ratio = 0.3
min_common = 4
pearson_thresh = 0.3
crmsd_thresh = 0.8
std_threshold = .6

# %%
max_heavy = 15
max_ratio = 0.35

min_common = 4

pearson_thresh = 0.3
crmsd_thresh = 0.8

std_threshold = .8

# %%
# !ls ../data/exp/STL/
# Out:
# oneADMET_LR-STL---Stability$_{microsomal}$ (MOUSE).parquet
# oneADMET_LR-STL---Stability$_{microsomal}$ (RAT).parquet
# oneADMET_LR-STL---logBB.parquet
# oneADMET_LR-STL---logClearance$_{microsomal}$ (MOUSE, µL·min⁻¹·kg⁻¹).parquet
# oneADMET_LR-STL---logClearance$_{microsomal}$ (RAT, µL·min⁻¹·kg⁻¹).parquet
# oneADMET_LR-STL---logClearance$_{renal}$ (µL·min⁻¹·kg⁻¹).parquet
# oneADMET_LR-STL---logClearance$_{total}$ (iv, RAT, µL·min⁻¹·kg⁻¹).parquet
# oneADMET_LR-STL---logD$_{7-4}$.parquet
# oneADMET_LR-STL---logER (MDCK-MDR1).parquet
# oneADMET_LR-STL---logER Caco-2.parquet
# oneADMET_LR-STL---logHalf-life$_{microsomal}$ (HUMAN, h).parquet
# oneADMET_LR-STL---logHalf-life$_{microsomal}$ (RAT, h).parquet
# oneADMET_LR-STL---logHalf-life$_{plasma}$ (HUMAN, h).parquet
# oneADMET_LR-STL---logHalf-life$_{plasma}$ (RAT, h).parquet
# oneADMET_LR-STL---logMRTD (mol·kg⁻¹).parquet
# oneADMET_LR-STL---logP$_{app}$ (Caco-2).parquet
# oneADMET_LR-STL---logP$_{app}$ (MDCK-LE).parquet
# oneADMET_LR-STL---logP$_{app}$ (MDCK-MDR1).parquet
# oneADMET_LR-STL---logP$_{app}$ (PAMPA).parquet
# oneADMET_LR-STL---logP$_{ow}$.parquet
# oneADMET_LR-STL---logS$_{buffer}$.parquet
# oneADMET_LR-STL---logS$_{water}$.parquet
# oneADMET_LR-STL---logVD$_{ss}$ (DOG, L·kg⁻¹).parquet
# oneADMET_LR-STL---pGI$_{50}$ Tumor-growth.parquet
# oneADMET_LR-STL---pIC$_{50}$ 4EBP1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ 5HT1A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ 5HT1A (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ 5HT1B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ 5HT1B (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ 5HT1D (PIG).parquet
# oneADMET_LR-STL---pIC$_{50}$ 5HT2A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ 5HT2A (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ 5HT3A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ 5HT3A (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ 5HT4R (CAVPO).parquet
# oneADMET_LR-STL---pIC$_{50}$ 5HT6R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ 5NTD (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ 8ODP (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ A4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AA1R (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ AA2AR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AA2BR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AA3R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AAK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ABC3G (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ABCG2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ABL1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ABL2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACACA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACACA (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACACB (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACE (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACE2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACES (BOVIN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACES (ELEEL).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACES (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACES (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACES (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACES (TETCF).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACHA3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACHA3 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACHA4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACHA4 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACHA7 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACKR3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACM1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACM1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACM2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACM2 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACM3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACM4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACOD1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACRO (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ACVL1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ADA17 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ADA17 (PIG).parquet
# oneADMET_LR-STL---pIC$_{50}$ ADA1B (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ ADA2A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ADK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ADRB1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ADRB2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AGTR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AGTR1 (RABIT).parquet
# oneADMET_LR-STL---pIC$_{50}$ AGTR2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AGTR2 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ AGTRA (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ AK1C3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AKT1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AKT2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AL5AP (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ALDR (BOVIN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ALDR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ALDR (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ ALK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AMPC (ENTCL).parquet
# oneADMET_LR-STL---pIC$_{50}$ AMPN (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AMPN (PIG).parquet
# oneADMET_LR-STL---pIC$_{50}$ AMPN (PLAF7).parquet
# oneADMET_LR-STL---pIC$_{50}$ ANDR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ANDR (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ ANDR (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ ANM1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ANM5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ANM6 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AOC3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AOC3 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ AOFA (BOVIN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AOFA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AOFA (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ AOFB (BOVIN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AOFB (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AOFB (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ APAF (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ APEX1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ APJ (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ARBK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ARF6 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ARGI1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ASM (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ATM (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ATP4A (PIG).parquet
# oneADMET_LR-STL---pIC$_{50}$ ATR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ATRIP (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ATS4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ATS5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AURKA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ AURKA (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ AURKB (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ B2CL1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ B2LA1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BACE1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BACE2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BCAT1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BCL2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BGAL (BOVIN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BGLR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BIRC2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BIRC3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BKRB2 (CAVPO).parquet
# oneADMET_LR-STL---pIC$_{50}$ BKRB2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BLAB (SERMA).parquet
# oneADMET_LR-STL---pIC$_{50}$ BLAN1 (KLEPN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BLAT (ECOLX).parquet
# oneADMET_LR-STL---pIC$_{50}$ BMP1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BMR1A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BRAF (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BRD2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BRD3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BRD4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BRS3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BTK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BUB1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ BXA1 (CLOBO).parquet
# oneADMET_LR-STL---pIC$_{50}$ C11B1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ C11B2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ C5AR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CAC1B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CAC1C (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CAC1C (RABIT).parquet
# oneADMET_LR-STL---pIC$_{50}$ CAC1G (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CAC1H (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CAC1I (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CAH1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CAH2 (BOVIN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CAH2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CALRL (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CAN1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CASP1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CASP3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CASP7 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CATB (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CATC (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CATD (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CATK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CATL1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CATS (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CBP (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CCG8 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CCKAR (CAVPO).parquet
# oneADMET_LR-STL---pIC$_{50}$ CCKAR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CCKAR (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ CCNC (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CCNH (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CCNT1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CCR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CCR2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CCR3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CCR4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CCR5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CCR6 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CD38 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CD5R1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CDK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CDK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CDK4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CDK5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CDK6 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CETP (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CFAB (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CFAD (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CFTR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CH60 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CHK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CHK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CHKA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CHLE (HORSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ CHLE (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CLK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CLTR1 (CAVPO).parquet
# oneADMET_LR-STL---pIC$_{50}$ CLTR2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CML1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CNR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CNR1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ CNR2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CP24A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CP2C9 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CP2D6 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CP3A4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CRTN (STAAE).parquet
# oneADMET_LR-STL---pIC$_{50}$ CSF1R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CSF1R (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ CSK21 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CSK22 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CSK23 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CSK2B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CXCR2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CXCR3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CXCR3 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ CXL10 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ CYP17A (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ CYSP (TRYCR).parquet
# oneADMET_LR-STL---pIC$_{50}$ Cell-prolif.parquet
# oneADMET_LR-STL---pIC$_{50}$ DCNL1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DDB1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DDR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DDR2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DDX3X (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DGAT1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DGAT1 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ DGLA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DHB1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DHB2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DHI1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DHI1 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ DHI2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DNLJ (STAAU).parquet
# oneADMET_LR-STL---pIC$_{50}$ DOPO (BOVIN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DOPO (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ DPP2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DPP4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DPP4 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ DPP9 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DRD2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DRD2 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ DRD3 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ DRTS (PLAFK).parquet
# oneADMET_LR-STL---pIC$_{50}$ DRTS (TOXGO).parquet
# oneADMET_LR-STL---pIC$_{50}$ DUT (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ DXR (MYCTU).parquet
# oneADMET_LR-STL---pIC$_{50}$ DYR (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ DYR (PNECA).parquet
# oneADMET_LR-STL---pIC$_{50}$ DYR (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ DYRK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ E2AK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EAA1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EAA2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EAA3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ECE1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ EDNRA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EDNRA (PIG).parquet
# oneADMET_LR-STL---pIC$_{50}$ EDNRA (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ EDNRB (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EDNRB (PIG).parquet
# oneADMET_LR-STL---pIC$_{50}$ EDNRB (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ EED (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EF2K (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EGFR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EGLN1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EGLN2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EHMT1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EHMT2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ELNE (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ENPP1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ENPP2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ENV (HV1H2).parquet
# oneADMET_LR-STL---pIC$_{50}$ EP300 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EPAS1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ERBB2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ERN1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ERR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ESR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ESR2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EST1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EST2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ EZH2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ F13A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ F16P1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ F264 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FA10 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FA11 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FA12 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FA9 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FAAH1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FAAH1 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ FAAH1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ FABH (MYCTU).parquet
# oneADMET_LR-STL---pIC$_{50}$ FABI (STAAR).parquet
# oneADMET_LR-STL---pIC$_{50}$ FABP4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FABP5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FAK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FAK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FAS (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FEN1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FGFR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FGFR2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FGFR3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FGFR4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FGFR4 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ FLT3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FNTA (BOVIN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FNTA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FNTA (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ FNTB (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FOLH1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FTO (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ FUCO (BOVIN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GASR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GASR (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ GASR (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ GCKR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GCR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GGPPS (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GHSR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GLR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GLR (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ GLSK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GLYC (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GLYM (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GNRHR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GPR35 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GRIA1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GRIK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GRK5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GRK6 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GRM1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GRM1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ GRM2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GRM2 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ GRM5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GRM5 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ GSK3A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GSK3B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GSTP1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GTR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GTR9 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ GYRA (ECOLI).parquet
# oneADMET_LR-STL---pIC$_{50}$ GYRB (MYCSM).parquet
# oneADMET_LR-STL---pIC$_{50}$ GYRB (MYCTU).parquet
# oneADMET_LR-STL---pIC$_{50}$ GYRB (STAAU).parquet
# oneADMET_LR-STL---pIC$_{50}$ HAOX1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HBSAG (HBVD3).parquet
# oneADMET_LR-STL---pIC$_{50}$ HDA11 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HDAC1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HDAC2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HDAC3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HDAC4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HDAC5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HDAC6 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HDAC7 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HDAC8 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HMDH (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HMDH (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ HPPD (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HRH1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HRH3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HS90A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HS90B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HSF1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HYEP (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HYES (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ HYES (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ I23O1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ICAM1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ICMT (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ IDHC (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ IGF1R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ IKKA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ IKKB (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ IKKE (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ IL2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ IMDH2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ INHA (MYCTU).parquet
# oneADMET_LR-STL---pIC$_{50}$ INSR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ IRAK4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ITA2B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ITA4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ITAL (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ITB3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ITB5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ITK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ JAK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ JAK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ JAK3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KAT2B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KAT6A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KC1A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KC1D (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KC1E (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KCC1D (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KCC2D (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KCNA3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KCNA5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KCNH2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KCNJ3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KCNN2 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ KCNN4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KDM1A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KDM2B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KDM4A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KDM4B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KDM4E (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KDM5A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KDM5C (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KGP (PORG3).parquet
# oneADMET_LR-STL---pIC$_{50}$ KHK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KIF11 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KISSR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KITH (HHV1S).parquet
# oneADMET_LR-STL---pIC$_{50}$ KLK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KLK7 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KLKB1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KMO (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KPCA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KPCB (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ KPCD (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KPCT (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KPCZ (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KPCZ (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ KS6B1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KSYK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ KTHY (MYCTU).parquet
# oneADMET_LR-STL---pIC$_{50}$ LCAP (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LCAP (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ LCK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LDHA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LEF (BACAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LGMN (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LIPE (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LKHA4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LMBL1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LOX5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LOX5 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ LOX5 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ LOXL2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LPXC (ECOLI).parquet
# oneADMET_LR-STL---pIC$_{50}$ LPXC (PSEAE).parquet
# oneADMET_LR-STL---pIC$_{50}$ LRRK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LST8 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LT4R2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LTC4S (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LUCI (PHOPY).parquet
# oneADMET_LR-STL---pIC$_{50}$ LYAM2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LYAM3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LYN (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ LYOX (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ M3K14 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ M3K5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ M3K7 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ M4K1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MAL12 (YEAST).parquet
# oneADMET_LR-STL---pIC$_{50}$ MALT1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MAP11 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MAP2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MAPK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MBOA4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MC4R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MCHR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MCHR1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ MCL1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MCR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MDM2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MDR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MELK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MEN1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MEP1B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MERTK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MET (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MGAL (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MGAT2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MGLL (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MIF (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MK01 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MK06 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MK07 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MK08 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MK09 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MK10 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MK14 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MKNK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MKNK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MMP1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MMP12 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MMP13 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MMP14 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MMP2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MMP3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MMP7 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MMP8 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MMP9 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MP2K1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MPIP2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MPIP3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MRAY (ECOLI).parquet
# oneADMET_LR-STL---pIC$_{50}$ MRP1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MSHR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MTOR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MTP (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ MURC (ECOLI).parquet
# oneADMET_LR-STL---pIC$_{50}$ MURI (HELPJ).parquet
# oneADMET_LR-STL---pIC$_{50}$ NAMPT (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NANH (CLOPF).parquet
# oneADMET_LR-STL---pIC$_{50}$ NFKB1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NK1R (CAVPO).parquet
# oneADMET_LR-STL---pIC$_{50}$ NK1R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NK2R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NK3R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NMDE2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NMDE2 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ NMDE3 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ NMDZ1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ NMT1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NOD1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NOD2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NOS1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NOS2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NOS2 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ NOS3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NOTUM (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NPBW1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NPY1R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NPY2R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NPY5R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NQO2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NR1H4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NRAM (I33A0).parquet
# oneADMET_LR-STL---pIC$_{50}$ NRAM (I34A1).parquet
# oneADMET_LR-STL---pIC$_{50}$ NRAM (I75A5).parquet
# oneADMET_LR-STL---pIC$_{50}$ NRAM (I77AB).parquet
# oneADMET_LR-STL---pIC$_{50}$ NRAM (INBLE).parquet
# oneADMET_LR-STL---pIC$_{50}$ NRP1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NTRK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NTRK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ NTRK3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ OPRD (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ OPRD (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ OPRK (CAVPO).parquet
# oneADMET_LR-STL---pIC$_{50}$ OPRK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ OPRM (CAVPO).parquet
# oneADMET_LR-STL---pIC$_{50}$ OPRM (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ OPRM (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ OPRX (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ OX1R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ OX2R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ OXDA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ OXER1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ P2RX2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ P2RX3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ P2RX7 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ P2RX7 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ P2RY1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ P2Y12 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ P2Y14 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ P3C2A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ P85A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ P85B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PA (I34A1).parquet
# oneADMET_LR-STL---pIC$_{50}$ PA21B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PA24A (BOVIN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PA2GA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PA2GX (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PAFA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PAI1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PAK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PAR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PAR4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PARG (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PARP1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PARP2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PCP (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PD1L1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PD2R2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE10 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE10 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE10 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE11 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE1A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE1B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE1C (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE2A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE3A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE3B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE4A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE4B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE4B (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE4C (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE4D (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE5A (BOVIN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE5A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE7A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDE9A (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PDPK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PE2R1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PE2R3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PEX14 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PGDH (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PGFRA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PGFRB (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PGH1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PGH1 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ PGH1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ PGH2 (BOVIN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PGH2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PGH2 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ PGH2 (SHEEP).parquet
# oneADMET_LR-STL---pIC$_{50}$ PGK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PI4KB (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PIM1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PIM2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PIM3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PK3CA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PK3CB (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PK3CD (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PK3CG (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PK3CG (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ PLD1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PLD2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PLK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PLK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PLK3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PLMN (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PMYT1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ POL (HV1B1).parquet
# oneADMET_LR-STL---pIC$_{50}$ POL (HV1BR).parquet
# oneADMET_LR-STL---pIC$_{50}$ POL (HV1H2).parquet
# oneADMET_LR-STL---pIC$_{50}$ POL (HV1N5).parquet
# oneADMET_LR-STL---pIC$_{50}$ POLG (HCV77).parquet
# oneADMET_LR-STL---pIC$_{50}$ POLG (HCVBK).parquet
# oneADMET_LR-STL---pIC$_{50}$ POLG (HCVCO).parquet
# oneADMET_LR-STL---pIC$_{50}$ PPARA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PPARG (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PPBN (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PPBT (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PPCE (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PPIA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PPO2 (AGABI).parquet
# oneADMET_LR-STL---pIC$_{50}$ PRGR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PRKDC (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PSB2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PSB5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PSB8 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PSDE (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PSN1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PTAFR (CAVPO).parquet
# oneADMET_LR-STL---pIC$_{50}$ PTAFR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PTGES (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PTN1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PTN11 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PTN2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PYGL (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PYRD (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ PYRD (PLAF7).parquet
# oneADMET_LR-STL---pIC$_{50}$ QPCT (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ R1AB (SARS).parquet
# oneADMET_LR-STL---pIC$_{50}$ R1AB (SARS2).parquet
# oneADMET_LR-STL---pIC$_{50}$ RAF1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ RASK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ RENI (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ RET (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ RIPK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ RIPK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ RIR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ROCK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ROCK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ RORB (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ RORG (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ROS1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ RPGF3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ RXRA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ S1PR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ S1PR2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ S1PR3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ S1PR4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ S1PR5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ S22AC (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ S29A1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ S5A1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ S5A2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ S6A13 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ SAHH (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SC5A1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SC5A2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SC6A1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SC6A1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ SC6A2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SC6A3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SC6A3 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ SC6A4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SC6A4 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ SC6A9 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SCAF (HCMVA).parquet
# oneADMET_LR-STL---pIC$_{50}$ SCD (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SCD5 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SCN1A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SCN1A (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ SCN2A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SCN2A (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ SCN5A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SCN9A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SCN9A (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ SCNAA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SCNAA (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ SEPR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SERA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SGK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SGMR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SGMR1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ SH2B2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SIR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SIR2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SL9A1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SL9A3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SMO (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SMO (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ SMYD2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SMYD3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SOAT1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SOAT1 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ SOAT1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ SOAT2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SORT (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SOS1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SPHK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SPHK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SRC (CHICK).parquet
# oneADMET_LR-STL---pIC$_{50}$ SRC (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SRPK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SSR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SSR2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SSR3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ST17A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ ST17B (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ STAT3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ STAT3 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ STAT6 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SUIS (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ SUMO1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ SUV92 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ T23O (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TA2R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TAF1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TAU (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TBK1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TERA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TERT (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TF (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TGFR1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ THA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ THAS (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ THB (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ THRB (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TIE2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TLR4 (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ TLR7 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TLR8 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TLR9 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TNFA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TNIK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TNKS1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TNKS2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TNR1A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TOP1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TPA (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TPH1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TRPA1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TRPA1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ TRPC6 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TRPM8 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TRPV1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TRPV1 (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ TRPV4 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TRY1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TTK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TXK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TYDP1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TYDP2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TYK2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TYPH (ECOLI).parquet
# oneADMET_LR-STL---pIC$_{50}$ TYRO3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ TYSY (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ UFO (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ UPAR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ URE1 (HELPY).parquet
# oneADMET_LR-STL---pIC$_{50}$ UREA (CANEN).parquet
# oneADMET_LR-STL---pIC$_{50}$ UROK (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ V1AR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ V1BR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ V2R (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ V2R (RAT).parquet
# oneADMET_LR-STL---pIC$_{50}$ VCAM1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ VDR (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ VGFR2 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ VGFR3 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ VHL (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ VNN1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ WEE1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ WNT1 (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ WNT3A (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ WNT3A (MOUSE).parquet
# oneADMET_LR-STL---pIC$_{50}$ XDH (BOVIN).parquet
# oneADMET_LR-STL---pIC$_{50}$ XDH (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ XIAP (HUMAN).parquet
# oneADMET_LR-STL---pIC$_{50}$ hERG (HAMSTER).parquet
# oneADMET_LR-STL---pK$_{d}$ AA1R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ ABL1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ BCL6 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ BRD4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ CAH1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ CAH2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ CAH7 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ CSK21 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ EGFR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ FAK1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ FGF2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ GRB2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ KEAP1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ LEG1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ LEG3 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ LEG9 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ M3K12 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ MET (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ MK14 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ NTRK1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ P3C2A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ PK3CD (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ PPIA (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ PPIF (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ R1AB (SARS2).parquet
# oneADMET_LR-STL---pK$_{d}$ RARB (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ RARG (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ RASK (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ RORB (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ RORG (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ RXRA (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ S1PR2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ SHBG (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ SOS1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ TA2R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ VGFR2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ WDR5 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{d}$ XIAP (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ 5HT1A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ 5HT1A (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ 5HT1B (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ 5HT1D (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ 5HT2A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ 5HT2A (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ 5HT2C (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ 5HT3A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ 5HT5A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ 5HT6R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ 5HT7R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ A4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ AA1R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ AA1R (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ AA2AR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ AA2AR (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ AA2BR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ AA3R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ AA3R (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ ABL1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ACES (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ACHA3 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ACHA4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ACHA4 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ ACHA7 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ACHA7 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ ACM1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ACM1 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ ACM2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ACM2 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ ACM3 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ACM3 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ ACM4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ACM5 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ADA1A (BOVIN).parquet
# oneADMET_LR-STL---pK$_{i}$ ADA1A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ADA1A (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ ADA1B (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ADA1B (MESAU).parquet
# oneADMET_LR-STL---pK$_{i}$ ADA1B (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ ADA1D (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ADA1D (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ ADA2A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ADA2A (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ ADA2B (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ADA2C (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ADRB1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ AGTR2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ AL5AP (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ AMPC (ECOLI).parquet
# oneADMET_LR-STL---pK$_{i}$ AMPN (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ AMPN (PIG).parquet
# oneADMET_LR-STL---pK$_{i}$ ANDR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ANDR (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ AOFA (BOVIN).parquet
# oneADMET_LR-STL---pK$_{i}$ AOFA (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ AOFA (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ AOFB (BOVIN).parquet
# oneADMET_LR-STL---pK$_{i}$ AOFB (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ B2CL1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ BACE1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ BCL2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ BCL2 (MOUSE).parquet
# oneADMET_LR-STL---pK$_{i}$ BKRB2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ BRD4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ C1S (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CAH1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CAH12 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CAH13 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CAH13 (MOUSE).parquet
# oneADMET_LR-STL---pK$_{i}$ CAH14 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CAH2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CAH3 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CAH4 (BOVIN).parquet
# oneADMET_LR-STL---pK$_{i}$ CAH4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CAH5A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CAH5B (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CAH6 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CAH7 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CAH9 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CALRL (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CAN (CANAL).parquet
# oneADMET_LR-STL---pK$_{i}$ CAN1 (PIG).parquet
# oneADMET_LR-STL---pK$_{i}$ CAN2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CASP1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CATB (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CATG (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CATK (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CATL1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CATS (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CCR1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CCR2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CCR3 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CDK2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CDK4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CHLE (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CNR1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CNR1 (MOUSE).parquet
# oneADMET_LR-STL---pK$_{i}$ CNR1 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ CNR2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CNR2 (MOUSE).parquet
# oneADMET_LR-STL---pK$_{i}$ CNR2 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ CRFR1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CRFR1 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ CSK21 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CTNB1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CXCR1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CXCR2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CXCR3 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CYP3A4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ CYSP (TRYCR).parquet
# oneADMET_LR-STL---pK$_{i}$ DHI1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ DPEP1 (PIG).parquet
# oneADMET_LR-STL---pK$_{i}$ DPO3 (BACSU).parquet
# oneADMET_LR-STL---pK$_{i}$ DPP4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ DRD1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ DRD1 (PIG).parquet
# oneADMET_LR-STL---pK$_{i}$ DRD1 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ DRD2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ DRD2 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ DRD3 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ DRD3 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ DRD4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ DRD5 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ DYR (CHICK).parquet
# oneADMET_LR-STL---pK$_{i}$ DYR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ DYR (LACCA).parquet
# oneADMET_LR-STL---pK$_{i}$ E2AK4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ EDNRB (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ELNE (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ENTK (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ESR1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ESR2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ EST1 (RABIT).parquet
# oneADMET_LR-STL---pK$_{i}$ FA10 (BOVIN).parquet
# oneADMET_LR-STL---pK$_{i}$ FA10 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ FA11 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ FA12 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ FA7 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ FA9 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ FAAH1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ FEN1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ FKB1A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ FURIN (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ GASR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ GASR (MOUSE).parquet
# oneADMET_LR-STL---pK$_{i}$ GBA1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ GBRA4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ GCR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ GCYA1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ GLR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ GNRHR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ GNRHR (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ GRIA2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ GRIK1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ GRIK1 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ GRM1 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ GRM2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ GRM5 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ GRM5 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ GSK3B (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ HDAC2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ HDAC6 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ HDAC8 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ HRH1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ HRH2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ HRH3 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ HRH3 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ HRH4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ HS90A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ HS90B (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ HYES (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ I23O1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ITK (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ JAK1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ JAK2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ KCNH2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ KDM1A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ KISSR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ KLK (PIG).parquet
# oneADMET_LR-STL---pK$_{i}$ KPCA (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ LEF (BACAN).parquet
# oneADMET_LR-STL---pK$_{i}$ LRRK2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ M3K12 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ M4K1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MC3R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MC4R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MC5R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MCHR1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MCL1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MCR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MDM2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MK01 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MK10 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MK14 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MMP1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MMP13 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MMP2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MMP8 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MMP9 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MSHR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ MTCA1 (MYCTU).parquet
# oneADMET_LR-STL---pK$_{i}$ MTR1A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ NISCH (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ NK1R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ NK2R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ NMDE2 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ NMDZ1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ NMDZ1 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ NOS1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ NOS1 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ NOS3 (BOVIN).parquet
# oneADMET_LR-STL---pK$_{i}$ NOX1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ NOX4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ NPY1R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ NPY2R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ NPY4R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ NPY5R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ OPRD (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ OPRD (MOUSE).parquet
# oneADMET_LR-STL---pK$_{i}$ OPRD (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ OPRK (CAVPO).parquet
# oneADMET_LR-STL---pK$_{i}$ OPRK (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ OPRK (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ OPRM (CAVPO).parquet
# oneADMET_LR-STL---pK$_{i}$ OPRM (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ OPRM (MOUSE).parquet
# oneADMET_LR-STL---pK$_{i}$ OPRM (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ OX1R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ OX1R (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ OX2R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ OX2R (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ OXYR (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ P2RX7 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ P2RX7 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ P2RY1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ P2Y12 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ P85A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PAK4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PAPA1 (CARPA).parquet
# oneADMET_LR-STL---pK$_{i}$ PARP1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PD2R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PD2R2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PDE10 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PDE2A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PDE4B (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PDE5A (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PE2R3 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PE2R3 (MOUSE).parquet
# oneADMET_LR-STL---pK$_{i}$ PE2R4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PE2R4 (MOUSE).parquet
# oneADMET_LR-STL---pK$_{i}$ PGFRB (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PIM1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PK3CA (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PLK1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PLMN (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PNMT (BOVIN).parquet
# oneADMET_LR-STL---pK$_{i}$ PNOC (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ POL (HV1BR).parquet
# oneADMET_LR-STL---pK$_{i}$ POL (HV1H2).parquet
# oneADMET_LR-STL---pK$_{i}$ PPARG (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PPIA (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PPOX (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PRGR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PSB5 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PTAFR (CAVPO).parquet
# oneADMET_LR-STL---pK$_{i}$ PTN1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PTN5 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PYGM (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ PYRD (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ QPCT (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ R1A (SARS2).parquet
# oneADMET_LR-STL---pK$_{i}$ R1AB (SARS).parquet
# oneADMET_LR-STL---pK$_{i}$ RENI (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ RIPK1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ROCK2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ S5A1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ SAHH (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ SC6A1 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ SC6A2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ SC6A3 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ SC6A3 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ SC6A4 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ SC6A4 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ SGMR1 (CAVPO).parquet
# oneADMET_LR-STL---pK$_{i}$ SGMR1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ SGMR1 (MOUSE).parquet
# oneADMET_LR-STL---pK$_{i}$ SGMR2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ SGMR2 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ SLK (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ SOS1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ SRC (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ SSR1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ SSR2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ ST14 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ STAT3 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ TAA7B (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ TAAR1 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ TAU (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ THRB (BOVIN).parquet
# oneADMET_LR-STL---pK$_{i}$ THRB (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ TMPS6 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ TNFA (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ TPA (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ TRPV1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ TRPV1 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ TRY1 (BOVIN).parquet
# oneADMET_LR-STL---pK$_{i}$ TRY1 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ TRY2 (BOVIN).parquet
# oneADMET_LR-STL---pK$_{i}$ TRYB2 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ TSPO (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ TYSY (MOUSE).parquet
# oneADMET_LR-STL---pK$_{i}$ UFO (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ UR2R (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ UROK (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ V1BR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ VACHT (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ VDR (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ VMAT2 (RAT).parquet
# oneADMET_LR-STL---pK$_{i}$ WDR5 (HUMAN).parquet
# oneADMET_LR-STL---pK$_{i}$ hERG (HAMSTER).parquet
# oneADMET_LR-STL---pLD$_{50}$ (po, RAT, mg·kg⁻¹).parquet
# oneADMET_LR-STL---pTD$_{50}$ (RAT).parquet

# %% [markdown]
# # 2) Augment

# %%
dataset =  'oneADMET_LR-STL---pIC$_{50}$ TGFR1 (HUMAN).parquet' #  'oneADMET_LR-STL---pIC$_{50}$ TGFR1 (HUMAN).parquet' # oneADMET_LR-STL---logER Caco-2.parquet
df = pd.read_parquet(f'../data/exp/STL/{dataset}')
len(df)
# Out:
# 1991

# %%
df = pd.read_parquet(f'../data/exp/STL/{dataset}')
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

df_train = df[df["SET"]!="B"]
df_test = df[df["SET"]=="B"]

output_csv = f'../data/frag/{dataset}.csv'
MMPGenerator(df_train, output_csv=output_csv, symmetric=True, max_heavy=max_heavy, max_ratio=max_ratio, verbose=True).run()
augmentor = MMPAugmentorFixed(pd.read_csv(output_csv, on_bad_lines="skip") , min_common=min_common, pearson_thresh=pearson_thresh, crmsd_thresh=crmsd_thresh)
final_df3 = augmentor.run()
imputed_df = update_predicted_rows(final_df3)
clean_df = prepare_and_plot_prediction_vs_experiment_complete_with_output(imputed_df, std_threshold=std_threshold)
output_df = assign_set_from_inchikey(clean_df, df_train)
# Find InChIKeys in df_train not in output_df
missing_rows = df_train[~df_train['InChIKey'].isin(output_df['InChIKey'])]
# Add columns to match output_df structure
missing_rows['STD'] = None
missing_rows['AUG'] = False
# Reorder columns to match output_df
missing_rows = missing_rows[['InChIKey', 'SMILES', 'Y', 'STD', 'AUG', 'SET']]
# Append to output_df
full_aug_df = pd.concat([output_df, missing_rows], ignore_index=True)
# Out:
# 0) Fragments generation
# 1) Indexing
# 2) Canonical SMIRKS generation
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:27] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:33] WARNING: not removing hydrogen atom with dummy atom neighbors
# [10:08:33] WARNING: not removing hydrogen atom with dummy atom neighbors
# 3) Computing pairwise correlations: 100%|██████████| 21875805/21875805 [01:21<00:00, 267542.39it/s]
# 4) Augmenting data: 100%|██████████| 287/287 [00:02<00:00, 110.54it/s]
# 5) Updating predicted rows: 100%|██████████| 39900/39900 [00:05<00:00, 6747.31it/s]
# ⚠️  Empty product sets in 0 / 39900 (0.00%) of transformations
# 6) Preparing output file
# Invalid SMILES removed: 0 / 252766 (0.00%)
# 7) Standardizing SMILES: 100%|██████████| 252766/252766 [00:28<00:00, 8804.76it/s]
# 8) Generating InChIKeys: 100%|██████████| 252766/252766 [00:46<00:00, 5467.47it/s]
# /var/folders/2b/_90d0zxj2w3gcjdjskhc3xhw0000gn/T/ipykernel_3425/3012110650.py:509: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   output_df = pd.concat(
# /var/folders/2b/_90d0zxj2w3gcjdjskhc3xhw0000gn/T/ipykernel_3425/3210606671.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missing_rows['STD'] = None
# /var/folders/2b/_90d0zxj2w3gcjdjskhc3xhw0000gn/T/ipykernel_3425/3210606671.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missing_rows['AUG'] = False
# /var/folders/2b/_90d0zxj2w3gcjdjskhc3xhw0000gn/T/ipykernel_3425/3210606671.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_aug_df = pd.concat([output_df, missing_rows], ignore_index=True)

# %%
len(full_aug_df), len(clean_df), len(output_df), len(df_train)
# Out:
# (2048, 2030, 2030, 1789)

# %%
train_and_compare_models_external(full_aug_df, df_test)
# Out:
# 🔬 Starting model training on external test set...
# Generating fingerprints (train): 100%|██████████| 2048/2048 [00:02<00:00, 757.46it/s]
# Generating fingerprints (test): 100%|██████████| 202/202 [00:00<00:00, 756.96it/s]
# 🚜 Training on no-aug data...
# 🌱 Training on full augmented data...
#
# 📊 Evaluation on external test set:
# No AUG model => RMSE: 0.7350, R²: 0.6297
# AUG model => RMSE: 0.7510, R²: 0.6134
# /Users/pierre/miniconda3/envs/chemprop_v2/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/pierre/miniconda3/envs/chemprop_v2/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# {'RMSE_NoAug': 0.7350122517751948,
#  'R2_NoAug': 0.6296691636057494,
#  'RMSE_Aug': 0.7510260619220747,
#  'R2_Aug': 0.6133564804262641,
#  'N_Train_NoAug': 1789,
#  'N_Train_Aug': 2048,
#  'N_Test': 202}

# %%
len(full_aug_df), len(clean_df), len(output_df), len(df_train)
# Out:
# (2048, 2030, 2030, 1789)

# %%
train_and_compare_models_external(full_aug_df, df_test)
# Out:
# 🔬 Starting model training on external test set...
# Generating fingerprints (train): 100%|██████████| 2048/2048 [00:02<00:00, 734.17it/s]
# Generating fingerprints (test): 100%|██████████| 202/202 [00:00<00:00, 740.27it/s]
# 🚜 Training on no-aug data...
# 🌱 Training on full augmented data...
#
# 📊 Evaluation on external test set:
# No AUG model => RMSE: 0.7350, R²: 0.6297
# AUG model => RMSE: 0.7510, R²: 0.6134
# /Users/pierre/miniconda3/envs/chemprop_v2/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/pierre/miniconda3/envs/chemprop_v2/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# {'RMSE_NoAug': 0.7350122517751948,
#  'R2_NoAug': 0.6296691636057494,
#  'RMSE_Aug': 0.7510260619220749,
#  'R2_Aug': 0.6133564804262639,
#  'N_Train_NoAug': 1789,
#  'N_Train_Aug': 2048,
#  'N_Test': 202}

# %%
full_aug_df.AUG.value_counts()
# Out:
# AUG
# False    1789
# True      259
# Name: count, dtype: int64

# %%
show_top_aug_vs_nonaug(full_aug_df, n=16)

# %%
- densité couverture scaffold sur molécule + nmbre d'occurence
- network MMP , noAug  vs Aug 
- per scaffold, pairs generé vs pair exp.
- coverage avec le test -> NoAUG, AUG, AUGstrict
- 1 , 2 , 3 point d'ancrage validation
